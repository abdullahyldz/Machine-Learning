# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib
from random import randint

# %%
data = []
import matplotlib.pyplot as plt
for i in range(10):
    x = randint(1,10)
    y = randint(1,10)
    label = 'blue'
    data.append((x,y,label,+1))
    #plt.scatter(x,y,color = 'blue')
    #data.append((x,y))
for i in range(10):
    x = randint(1,10)
    y = randint(-10,-1)
    label = 'red'
    data.append((x,y,label,-1))
    #plt.scatter(x,y,color = 'red')

# %%
for point in data:
    plt.scatter(point[0],point[1],color = point[2])
for point in data:
    
xs = np.linspace(0,10,100)
h = [2,-5]
ys = h[0]*xs + h[1]
plt.plot(xs,ys)

# %%
import time
for i in range(4):
    for test in data:
        axes = plt.gca()
        axes.set_xlim([-5,15])
        axes.set_ylim([-10,10])
        xtest = test[0]
        ytest = test[1]
        estimate = h[0]*xtest + h[1]
        label = 'blue' if ytest-estimate>0 else 'red'
        flag = 1 if label =='blue' else -1
        print(xtest,ytest,estimate,flag)
        delta = flag-test[3]
        h[0] = h[0] + 2*delta*xtest
        h[1] = h[1] + 2*delta*ytest
        print(h[0],h[1])
        for point in data:
            plt.scatter(point[0],point[1],color = point[2])
        xs2 = np.linspace(0,10,100)
        ys2 = h[0]*xs + h[1]
        plt.plot(xs2,ys2)
        plt.show()
# Out:
# 6 10 -81 1
# 42 -333
# 5 1 -123 1
# 42 -333
# 5 5 -123 1
# 42 -333
# 1 2 -291 1
# 42 -333
# 3 6 -207 1
# 42 -333
# 7 8 -39 1
# 42 -333
# 4 8 -165 1
# 42 -333
# 8 1 3 -1
# 10 -337
# 4 1 -297 1
# 10 -337
# 9 7 -247 1
# 10 -337
# 2 -6 -317 1
# 18 -361
# 2 -6 -325 1
# 26 -385
# 7 -5 -203 1
# 54 -405
# 5 -6 -135 1
# 74 -429
# 9 -6 237 -1
# 74 -429
# 5 -7 -59 1
# 94 -457
# 9 -1 389 -1
# 94 -457
# 10 -7 483 -1
# 94 -457
# 9 -7 389 -1
# 94 -457
# 6 -1 107 -1
# 94 -457
# 6 10 107 -1
# 70 -497
# 5 1 -147 1
# 70 -497
# 5 5 -147 1
# 70 -497
# 1 2 -427 1
# 70 -497
# 3 6 -287 1
# 70 -497
# 7 8 -7 1
# 70 -497
# 4 8 -217 1
# 70 -497
# 8 1 63 -1
# 38 -501
# 4 1 -349 1
# 38 -501
# 9 7 -159 1
# 38 -501
# 2 -6 -425 1
# 46 -525
# 2 -6 -433 1
# 54 -549
# 7 -5 -171 1
# 82 -569
# 5 -6 -159 1
# 102 -593
# 9 -6 325 -1
# 102 -593
# 5 -7 -83 1
# 122 -621
# 9 -1 477 -1
# 122 -621
# 10 -7 599 -1
# 122 -621
# 9 -7 477 -1
# 122 -621
# 6 -1 111 -1
# 122 -621
# 6 10 111 -1
# 98 -661
# 5 1 -171 1
# 98 -661
# ...
